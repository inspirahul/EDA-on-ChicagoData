# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
chicago_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Chicago_Crime_Detective.csv")
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
chicago_data.head()
# Out:
#    Unnamed: 0       ID            Date            LocationDescription  Arrest  \
# 0           0  8951354  12/31/12 23:15                         STREET   False
# 1           1  8951141  12/31/12 22:00                         STREET   False
# 2           2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3           3  8952223  12/31/12 22:00                         STREET   False
# 4           4  8951608  12/31/12 21:30                         STREET   False
#
#    Domestic  Beat District CommunityArea  Year
# 0     False   623        6            69  2012
# 1     False  1213       12            24  2012
# 2     False  1622       16            11  2012
# 3     False   724        7            67  2012
# 4     False   211        2            35  2012

# %%
a = chicago_data['Year'].value_counts().sort_index()

# %%
plt.hist(a)
plt.show()

# %%
plt.plot(a,  marker='o')
plt.show()

# %%
b = chicago_data[chicago_data['Arrest']==True]

# %%
b
# Out:
#         Unnamed: 0       ID            Date             LocationDescription  \
# 5                5  8950793  12/31/12 20:30                          STREET
# 8                8  8951802  12/31/12 19:00                          STREET
# 13              13  8950570  12/31/12 16:20                     GAS STATION
# 47              47  8949895  12/30/12 19:46                           ALLEY
# 59              59  8949557  12/30/12 15:00                          STREET
# 69              69  8949844   12/30/12 7:15                          STREET
# 70              70  8949258   12/30/12 7:05                          STREET
# 74              74  8950331   12/30/12 3:00                          STREET
# 82              82  8949392   12/30/12 0:30                          STREET
# 85              85  8949625   12/30/12 0:00                          STREET
# 97              97  8948698  12/29/12 16:15                          STREET
# ...

# %%
TrueArrest = b['Year'].value_counts().sort_index()

# %%
TrueArrest
# Out:
# 2001    2152
# 2002    2115
# 2003    1798
# 2004    1693
# 2005    1528
# 2006    1302
# 2007    1212
# 2008    1020
# 2009     840
# 2010     701
# 2011     625
# 2012     550
# Name: Year, dtype: int64

# %%
TrueArrest.sum()
# Out:
# 15536

# %%
print("2001 to 2006 : ", TrueArrest[0:6].sum())
print("2007 to 2012 : ", TrueArrest[6:12].sum())
# Out:
# 2001 to 2006 :  10588
# 2007 to 2012 :  4948

# %%
plt.plot(TrueArrest,  marker='o')
plt.show()

# %%
chicago_data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Date', 'LocationDescription', 'Arrest', 'Domestic',
#        'Beat', 'District', 'CommunityArea', 'Year'],
#       dtype='object')

# %%
top5 = chicago_data['LocationDescription'].value_counts().head(6)

# %%
type(top5)
# Out:
# pandas.core.series.Series

# %%
top5.drop(labels='OTHER', inplace=True)

# %%
top5.sum()
# Out:
# 177510

# %%
top5
# Out:
# STREET                            156564
# PARKING LOT/GARAGE(NON.RESID.)     14852
# ALLEY                               2308
# GAS STATION                         2111
# DRIVEWAY - RESIDENTIAL              1675
# Name: LocationDescription, dtype: int64

# %%
chicago_data.head()
# Out:
#    Unnamed: 0       ID            Date            LocationDescription  Arrest  \
# 0           0  8951354  12/31/12 23:15                         STREET   False
# 1           1  8951141  12/31/12 22:00                         STREET   False
# 2           2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3           3  8952223  12/31/12 22:00                         STREET   False
# 4           4  8951608  12/31/12 21:30                         STREET   False
#
#    Domestic  Beat District CommunityArea  Year
# 0     False   623        6            69  2012
# 1     False  1213       12            24  2012
# 2     False  1622       16            11  2012
# 3     False   724        7            67  2012
# 4     False   211        2            35  2012

# %%
top5 = chicago_data['LocationDescription'].value_counts()

# %%
top5
# Out:
# STREET                                             156564
# PARKING LOT/GARAGE(NON.RESID.)                      14852
# OTHER                                                4573
# ALLEY                                                2308
# GAS STATION                                          2111
# DRIVEWAY - RESIDENTIAL                               1675
# RESIDENTIAL YARD (FRONT/BACK)                        1536
# RESIDENCE                                            1302
# RESIDENCE-GARAGE                                     1176
# VACANT LOT/LAND                                       985
# VEHICLE NON-COMMERCIAL                                817
# SIDEWALK                                              462
# CHA PARKING LOT/GROUNDS                               405
# AIRPORT/AIRCRAFT                                      363
# POLICE FACILITY/VEH PARKING LOT                       266
# PARK PROPERTY                                         255
# ...

# %%
chicago_data['Day'] = pd.DatetimeIndex(chicago_data['Date']).day

chicago_data['Week_Day'] = pd.DatetimeIndex(chicago_data['Date']).weekday

chicago_data['Month'] = pd.DatetimeIndex(chicago_data['Date']).month

# %%
chicago_data.head()
# Out:
#    Unnamed: 0       ID            Date            LocationDescription  Arrest  \
# 0           0  8951354  12/31/12 23:15                         STREET   False
# 1           1  8951141  12/31/12 22:00                         STREET   False
# 2           2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3           3  8952223  12/31/12 22:00                         STREET   False
# 4           4  8951608  12/31/12 21:30                         STREET   False
#
#    Domestic  Beat District CommunityArea  Year  Day  Week_Day  Month
# 0     False   623        6            69  2012   31         0     12
# 1     False  1213       12            24  2012   31         0     12
# 2     False  1622       16            11  2012   31         0     12
# 3     False   724        7            67  2012   31         0     12
# 4     False   211        2            35  2012   31         0     12

# %%
chicago_data.describe()
# Out:
#           Unnamed: 0            ID           Beat           Year  \
# count  191641.000000  1.916410e+05  191641.000000  191641.000000
# mean    95820.000000  4.968629e+06    1258.810771    2006.134940
# std     55322.135806  2.342997e+06     702.530465       3.520285
# min         0.000000  1.310022e+06     111.000000    2001.000000
# 25%     47910.000000  2.832144e+06     722.000000    2003.000000
# 50%     95820.000000  4.762956e+06    1121.000000    2006.000000
# 75%    143730.000000  7.201878e+06    1733.000000    2009.000000
# max    191640.000000  9.181151e+06    2535.000000    2012.000000
#
#                  Day       Week_Day          Month
# count  191641.000000  191641.000000  191641.000000
# mean       15.771698       2.996238       6.611518
# std         8.771161       1.985848       3.433006
# min         1.000000       0.000000       1.000000
# 25%         8.000000       1.000000       4.000000
# 50%        16.000000       3.000000       7.000000
# ...

# %%
chicago_data['Week_Day'].value_counts()
# Out:
# 4    29284
# 2    27416
# 0    27397
# 3    27319
# 5    27118
# 1    26791
# 6    26316
# Name: Week_Day, dtype: int64

# %%
chicago_data['WeekDayName'] = pd.DatetimeIndex(chicago_data['Date']).weekday_name

# %%
chicago_data['WeekDayName'].value_counts()
# Out:
# Friday       29284
# Wednesday    27416
# Monday       27397
# Thursday     27319
# Saturday     27118
# Tuesday      26791
# Sunday       26316
# Name: WeekDayName, dtype: int64

# %%
TrueArrest = chicago_data[chicago_data['Arrest']==True]

# %%
TrueArrest.Month.value_counts()
# Out:
# 1     1435
# 12    1397
# 10    1342
# 8     1329
# 7     1324
# 3     1298
# 11    1256
# 4     1252
# 9     1248
# 2     1238
# 6     1230
# 5     1187
# Name: Month, dtype: int64

# %%
Gas = chicago_data[chicago_data['LocationDescription']=='GAS STATION']

# %%
Gas.head()
# Out:
#      Unnamed: 0       ID            Date LocationDescription  Arrest  \
# 13           13  8950570  12/31/12 16:20         GAS STATION    True
# 106         106  8948353  12/29/12 10:00         GAS STATION   False
# 213         213  8945802  12/27/12 10:00         GAS STATION   False
# 278         278  8943877  12/25/12 10:00         GAS STATION   False
# 290         290  8943595  12/24/12 21:55         GAS STATION   False
#
#      Domestic  Beat District CommunityArea  Year  Day  Week_Day  Month  \
# 13      False   825        8            66  2012   31         0     12
# 106     False   823        8            66  2012   29         5     12
# 213     False   321        3            42  2012   27         3     12
# 278     False   332        3            43  2012   25         1     12
# 290     False   421        4            43  2012   24         0     12
#
#     WeekDayName
# 13       Monday
# 106    Saturday
# 213    Thursday
# 278     Tuesday
# 290      Monday

# %%
Gas['WeekDayName'].value_counts()
# Out:
# Saturday     338
# Sunday       336
# Friday       332
# Thursday     282
# Monday       280
# Wednesday    273
# Tuesday      270
# Name: WeekDayName, dtype: int64
